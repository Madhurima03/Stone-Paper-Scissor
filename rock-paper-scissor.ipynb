# %%
import random
cpoints=hpoints=0
print("Choose your move: \n1:Rock \n2:Paper \n3:Scissors")
while cpoints<5 or hpoints<5:
    hmove=int(input())
    if(hmove==1):
        print("\nYou have picked rock.")
    elif(hmove==2):
        print("\nYou have picked paper.")
    elif(hmove==3):
        print("\nYou have picked scissors.")
    else:
        print("\nInvalid move")
        hmove=int(input("\nChoose correct move: \n1:Rock \n2:Paper \n3:Scissors \n"))
    cmove=random.randint(1,4)
    if(cmove==1):
        print("\nThe computer has picked rock.")
    elif(cmove==2):
        print("\nThe computer has picked paper.")
    elif(cmove==3):
        print("\nThe computer has scissor.")
    if(hmove==1 and cmove==2):
        print("\nThe computer gains a point.\n")
        cpoints+=1
    elif(hmove==2 and cmove==3):
        print("\nThe computer gains a point.\n")
        cpoints+=1
    elif(hmove==3 and cmove==2):
        print("\nThe computer gains a point.\n")
        cpoints+=1
    elif(hmove==1 and cmove==3):
        print("\nYou gained a point.\n")
        hpoints+=1
    elif(hmove==3 and cmove==2):
        print("\nYou gained a point.\n")
        hpoints+=1
    elif(hmove==2 and cmove==1):
        print("\nYou gained a point.\n")
        hpoints+=1
    else:
        print("\n Both you and the computer have chosen the same move.\n")
        hmove=int(input())
if(cpoints==5):
    print("\n The computer has won. Sorry,you loose.")
else:
    print("\n You have won.")
# Out:
# Choose your move:
# 1:Rock
# 2:Paper
# 3:Scissors
#
# You have picked rock.
#
# The computer has scissor.
#
# You gained a point.
#
#
# You have picked paper.
#
# The computer has scissor.
#
# The computer gains a point.
#
#
# You have picked paper.
#
# The computer has picked rock.
#
# You gained a point.
#
#
# You have picked scissors.
#
# The computer has picked rock.
#
#  Both you and the computer have chosen the same move.
#
#
# Invalid move
#
# The computer has scissor.
#
#  Both you and the computer have chosen the same move.
#
#
# You have picked rock.
#
# The computer has scissor.
#
# You gained a point.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 5
#       3 print("Choose your move: \n1:Rock \n2:Paper \n3:Scissors")
#       4 while cpoints<5 or hpoints<5:
# ----> 5     hmove=int(input())
#       6     if(hmove==1):
# ...
